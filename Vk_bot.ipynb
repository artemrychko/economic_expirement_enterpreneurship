# %%
import vk_api
import time
import requests
import json
import pandas as pd
import numpy as np


v = vk_api.VkApi(login = telephone_number, password = your_password)
v.auth()
vk = v.get_api()

# %%
vk.messages.send(domain = 'natalie_polyanskaya', message =  'Привет, секс, люблю')
# Out:
# 554641

# %%
import datetime
datetime.datetime.fromtimestamp(messages[-1][-1]['date']).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2016-10-01 20:48:12'

# %%
num = 0
tot = 0
for k in range(len(messages)):
    for i in range(len(messages[k])):
        tot += 1
        if 'секс' in messages[k][i]['body']:
            num += 1
            print(messages[k][i]['body'])
print('Total is {}'.format(num))
# Out:
# [{'body': 'Хорошо',
#   'date': 1524240827,
#   'from_id': 25035372,
#   'id': 552654,
#   'out': 0,
#   'read_state': 1,
#   'user_id': 25035372},
#  {'body': 'Кушать приготовишь?',
#   'date': 1524240811,
#   'from_id': 166597414,
#   'id': 552653,
#   'out': 1,
#   'random_id': 0,
#   'read_state': 1,
#   'user_id': 25035372},
#  {'body': '❤️',
#   'date': 1524240803,
#   'emoji': 1,
#   'from_id': 25035372,
#   'id': 552652,
#   'out': 0,
#   'read_state': 1,
#   'user_id': 25035372},
#  {'body': 'С канты',
#   'date': 1524240795,
#   'from_id': 25035372,
#   'id': 552651,
#   'out': 0,
#   'read_state': 1,
#   'user_id': 25035372},
#  {'body': 'Давай\nБуду ждать \nЯ только домой еду',
#   'date': 1524240789,
#   'from_id': 25035372,
#   'id': 552650,
#   'out': 0,
#   'read_state': 1,
#   'user_id': 25035372},
#  {'body': 'К 9',
#   'date': 1524240637,
#   'from_id': 166597414,
#   'id': 552649,
#   'out': 1,
#   'random_id': 0,
#   'read_state': 1,
#   'user_id': 25035372},
# ...

# %%
# Out:
# Ты будешь брать попить или мне зайти?
# Если не брать во внимание, что я соскучилась (как всегда, естественно и неимоверно), то у мен все хорошо))
# На самом деле, я была на 80% уверена, что ты не позвонишь, около 2 легла спать, проснулась в 5, чтобы попить водички, убедилась в своём предположении и легла спать обратно, проснулась в 9)🙃
# Не знаю
# Не обратила внимание
# Попробуй посмотреть на сайте crazydays.ru
# Другой вопрос, что могут уже в первый день все разобрать😁
# Я не обратила внимания
# Запиши своего брата
# Забрать ключи на московский вокзал
# Обратно так, скорее всего ;)
# Как раз брата не будет дома
# У меня есть ключи
# Я с ним не встречусь
# Будет скучать и параллельно подумает над своим поведением😈😁
# Не
# Сначала по делам, так сказать девичьим - привести себя в порядок перед встречей с вами..😁
# Потом к брату
# Потом с подругами встречусь, они меня провожать будут)
# Да
# Просто вещи, которые я купила они у брата в Москве остались
# Я посмотрела
# ...

# %%
import vk_api
import time
import requests
import json
import pandas as pd
import numpy as np

v = vk_api.VkApi(login = number, password = password)
v.auth()
vk = v.get_api()

num = vk.messages.get(count = 1)['count']
all_messages = vk.messages.get(count = num)
t = pd.DataFrame({'colA': [1, 2, 3], 'colB': [2, 3, 5], 'colC':['Hi', 'Bye', 'Cool']})
text = t.to_string()
pd.DataFrame(vk.messages.getHistory(user_id = n)['items'])
users = vk.messages.getChat(chat_id = 2)['users']
for user in users:
    info = vk.users.get(user_id = user, fields = ' sex, bdate, city, country, home_town, domain, has_mobile, contacts, site, education, universities, schools, status, last_seen, followers_count, common_count, occupation, nickname, relatives, relation, personal, connections, exports, wall_comments, activities, interests, music, movies, tv, books, games, about, quotes, can_post, can_see_all_posts, can_see_audio, can_write_private_message, can_send_friend_request, is_favorite, is_hidden_from_feed, timezone, screen_name, maiden_name, crop_photo, is_friend, friend_status, career, military, blacklisted, blacklisted_by_me')
    print(info[0]['first_name'], info[0]['last_name'])
res = pd.read_csv(results)
for user in users:
    vk.messages.send(res[user], domain = user)

# %%
# Out:
#                                                  body        date    from_id  \
# 0   colA  colB  colC\n0     1     2    Hi\n1     2...  1524763717  444559241
# 1                                                colC  1524763668  444559241
# 2                                          AI is hear  1524763350  444559241
# 3                                                 хей  1524763144  444559241
# 4                                               тест3  1524763072  166597414
# 5                                               тест2  1524763070  166597414
# 6                                                Тес1  1524763067  166597414
# 7                                              привет  1524763055  166597414
# 8                                             Кто вы?  1521582498  166597414
# 9                               подключайся к овтетам  1521582476  444559241
# 10                   Слышал здесь не хватает спама:DD  1514331951  444559241
#
# ...

# %%
# Out:
# Лорд Демешев
# Артём Рычко
# Игорь Игамбердиев
